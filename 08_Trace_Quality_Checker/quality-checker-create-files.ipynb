# %%
import os
from pytextdist.preprocessing import phrase_preprocessing

# %%
# Diversity Metrics
import os
from pytextdist.preprocessing import phrase_preprocessing
from pytextdist.edit_distance import levenshtein_distance, levenshtein_similarity
from pytextdist.edit_distance import lcs_distance, lcs_similarity
from pytextdist.edit_distance import damerau_levenshtein_distance, damerau_levenshtein_similarity
from pytextdist.edit_distance import hamming_distance, hamming_similarity
from pytextdist.edit_distance import jaro_similarity, jaro_winkler_similarity
from pytextdist.vector_similarity import cosine_similarity
from pytextdist.vector_similarity import jaccard_similarity
from pytextdist.vector_similarity import sorensen_dice_similarity
from pytextdist.vector_similarity import qgram_similarity
import pandas as pd
import textdistance

pathReal = str(os.getcwd()) + '\CAEX\XES-MORGAN' + '\\'
pathLLM = str(os.getcwd()) + '\CAEX\XES-MORGAN-LLM-MISTRAL' + '\\'
print(pathReal)

pathFileNameResCsv = 'results_RQ1/CAEX/Diversity/Diversity-MISTRAL.csv'
pathFileNameResXlsx = 'results_RQ1/CAEX/Diversity/Diversity-MISTRAL.xlsx'

# 'XES-MORGAN-LLM-GEMINI', 'XES-MORGAN-LLM-GPT3.5', 'XES-MORGAN-LLM-GPT4', 'XES-MORGAN-LLM-LLAMA3', 
# 'XES-MORGAN-LLM-CLAUDE', 'XES-MORGAN-LLM-MISTRAL'
# 'Diversity-GEMINI', 'Diversity-GPT35', 'Diversity-GPT4', 'Diversity-LLAMA3', 'Diversity-CLAUDE', 'Diversity-MISTRAL'

data = []
for rootReal, dirsReal, filesReal in os.walk(pathReal):
    for fileReal in filesReal:
        if fileReal.endswith(".xes"):
            pathfileReal = pathReal + fileReal
            print(pathfileReal)
            file1Real = open(pathfileReal, 'r')
            LinesReal = file1Real.read()
            indexC = 0
            cosine = []
            jaccard = []
            sorensen_dice = []
            qgram = []
            for rootFake, dirsFake, filesFake in os.walk(pathLLM):
                for fileFake in filesFake:
                    if fileFake.endswith(".xes") and fileFake == fileReal:
                        pathfileFake = pathLLM + fileFake
                        file2Fake = open(pathfileFake, 'r')
                        LinesFake = file2Fake.read()
                        
                        # 'Hamming-Dist': hamming_distance(LinesReal, LinesFake),
                        # 'Hamming-Sim': hamming_similarity(LinesReal, LinesFake),
                        
                        data.append({'File': fileFake, 
                                     'Levenshtein-Dist': levenshtein_distance(LinesReal, LinesFake),
                                     'Levenshtein-Sim': levenshtein_similarity(LinesReal, LinesFake),
                                     'LCS-Dist': lcs_distance(LinesReal, LinesFake),
                                     'LCS-Sim': lcs_similarity(LinesReal, LinesFake),
                                     # 'Damerau-Levenshtein-Dist': damerau_levenshtein_distance(LinesReal, LinesFake),
                                     # 'Damerau-Levenshtein-Sim': damerau_levenshtein_similarity(LinesReal, LinesFake),
                                     'Overlap': textdistance.overlap(LinesReal, LinesFake),
                                     'Jaro-Sim': jaro_similarity(LinesReal, LinesFake),
                                     # 'Jaro-winkler-Sim': jaro_winkler_similarity(LinesReal, LinesFake),
                                     '1-cosine': cosine_similarity(LinesReal, LinesFake, n=1), 
                                     '2-cosine': cosine_similarity(LinesReal, LinesFake, n=2),
                                     '3-cosine': cosine_similarity(LinesReal, LinesFake, n=3),
                                     '4-cosine': cosine_similarity(LinesReal, LinesFake, n=4),
                                     '1-jaccard': jaccard_similarity(LinesReal, LinesFake, n=1), 
                                     '2-jaccard': jaccard_similarity(LinesReal, LinesFake, n=2),
                                     '3-jaccard': jaccard_similarity(LinesReal, LinesFake, n=3),
                                     '4-jaccard': jaccard_similarity(LinesReal, LinesFake, n=4),
                                     '1-sorensen_dice': sorensen_dice_similarity(LinesReal, LinesFake, n=1), 
                                     '2-sorensen_dice': sorensen_dice_similarity(LinesReal, LinesFake, n=2),
                                     '3-sorensen_dice': sorensen_dice_similarity(LinesReal, LinesFake, n=3),
                                     '4-sorensen_dice': sorensen_dice_similarity(LinesReal, LinesFake, n=4),
                                     '1-qgram': qgram_similarity(LinesReal, LinesFake, n=1), 
                                     '2-qgram': qgram_similarity(LinesReal, LinesFake, n=2),
                                     '3-qgram': qgram_similarity(LinesReal, LinesFake, n=3),
                                     '4-qgram': qgram_similarity(LinesReal, LinesFake, n=4) })
                        print(f"Done:{fileFake}")
                   
# Saving first group of data to a single excel file
df = pd.DataFrame(data, columns=['File', 
                                 'Levenshtein-Dist', 'Levenshtein-Sim', 
                                 'LCS-Dist', 'LCS-Sim', 
                                 # 'Damerau-Levenshtein-Dist', 'Damerau-Levenshtein-Sim', 
                                 'Overlap',
                                 'Jaro-Sim', # 'Jaro-Winkler-Sim',
                                 '1-cosine', '2-cosine', '3-cosine', '4-cosine', 
                                 '1-jaccard', '2-jaccard', '3-jaccard', '4-jaccard',  
                                 '1-sorensen_dice', '2-sorensen_dice', '3-sorensen_dice', '4-sorensen_dice', 
                                 '1-qgram', '2-qgram', '3-qgram', '4-qgram'])   

df.to_excel(pathFileNameResXlsx, index=False)
df.to_csv(pathFileNameResCsv, index=False)
# Out:
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-07 08.04 Test-representations.airdM.xes
# Done:2023-02-07 08.04 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-07 09.06 Test-representations.airdM.xes
# Done:2023-02-07 09.06 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-07 09.17 Test-representations.airdM.xes
# Done:2023-02-07 09.17 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-07 09.27 Test-representations.airdM.xes
# Done:2023-02-07 09.27 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-07 09.48 Test-representations.airdM.xes
# Done:2023-02-07 09.48 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-07 10.55 Test-representations.airdM.xes
# Done:2023-02-07 10.55 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-07 11.07 Test-representations.airdM.xes
# Done:2023-02-07 11.07 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-08 09.01 Test-representations.airdM.xes
# Done:2023-02-08 09.01 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-08 13.19 Test-representations.airdM.xes
# Done:2023-02-08 13.19 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-08 14.30 Test-representations.airdM.xes
# Done:2023-02-08 14.30 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-09 08.10 Test-representations.airdM.xes
# Done:2023-02-09 08.10 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-09 10.13 Test-representations.airdM.xes
# Done:2023-02-09 10.13 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-09 13.33 Test-representations.airdM.xes
# Done:2023-02-09 13.33 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-09 13.37 Test-representations.airdM.xes
# Done:2023-02-09 13.37 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-10 08.43 Test-representations.airdM.xes
# Done:2023-02-10 08.43 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-10 08.50 Test-representations.airdM.xes
# Done:2023-02-10 08.50 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-10 08.58 Test-representations.airdM.xes
# Done:2023-02-10 08.58 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-10 09.38 Test-representations.airdM.xes
# Done:2023-02-10 09.38 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-10 10.09 Test-representations.airdM.xes
# Done:2023-02-10 10.09 Test-representations.airdM.xes
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-10 10.37 Test-representations.airdM.xes
# Done:2023-02-10 10.37 Test-representations.airdM.xes

# %%
# Correctness Metric (Syntax Check)
import os
from pytextdist.preprocessing import phrase_preprocessing
from pytextdist.edit_distance import levenshtein_distance, levenshtein_similarity
from pytextdist.vector_similarity import cosine_similarity
from pytextdist.vector_similarity import jaccard_similarity
import pandas as pd

pathSynth = str(os.getcwd()) + '\CAEX\Syntax.csv'
df_syntax = pd.read_csv(pathSynth)
print(df_syntax)

if ((df_syntax['event'] == 'event') & (df_syntax['class'] == 'SupportedRoleClass') & (df_syntax['featureName'] == 'roleClass') & (df_syntax['eventType'] == 'SET')).any():
    print('OK')
else:
    print('NO')
    
pathReal = str(os.getcwd()) + '\CAEX\XES-MORGAN' + '\\'
pathLLM = str(os.getcwd()) + '\CAEX\XES-MORGAN-LLM-CLAUDE' + '\\'
print(pathReal)

pathFileNameResXlsx = 'results_RQ1/CAEX/Correctness/Correctness-CLAUDE.xlsx'
pathFileNameResCsv = 'results_RQ1/CAEX/Correctness/Correctness-CLAUDE.csv'

# 'XES-MORGAN-LLM-GEMINI', 'XES-MORGAN-LLM-GPT3.5', 'XES-MORGAN-LLM-GPT4', 'XES-MORGAN-LLM-LLAMA3', 
# 'XES-MORGAN-LLM-CLAUDE', 'XES-MORGAN-LLM-MISTRAL'
# 'Correctness-GEMINI', 'Correctness-GPT35', 'Correctness-GPT4', 'Correctness-LLAMA3', 
# 'Correctness-CLAUDE', 'Correctness-MISTRAL'

data = []

for rootReal, dirsReal, filesReal in os.walk(pathLLM):
    for fileReal in filesReal:
        if fileReal.endswith(".xes"):
            pathfileReal = pathReal + fileReal
            print(pathfileReal)
            file1Real = open(pathfileReal, 'r')
            LinesReal = file1Real.readlines()
            countReal = 0
            countCorrect = 0
            # Strips the newline character
            for lineReal in LinesReal:
                countReal += 1
                str_a_beforeReal = lineReal
                str_a_afterReal = phrase_preprocessing(str_a_beforeReal, grain='word', ignore_case=False) # , ignore_case=False
                # print("Line{}: {}".format(count, line.strip()))
                # print("Line{}: {}".format(countReal, str_a_afterReal))
                # print(str_a_afterReal[0]+' '+str_a_afterReal[1]+' '+str_a_afterReal[2]+' '+str_a_afterReal[3])
                if ((df_syntax['event'] == str_a_afterReal[0]) & (df_syntax['class'] == str_a_afterReal[1]) & (df_syntax['featureName'] == str_a_afterReal[2]) & (df_syntax['eventType'] == str_a_afterReal[3])).any():
                    countCorrect += 1
                else:
                    print(str_a_afterReal[0]+' '+str_a_afterReal[1]+' '+str_a_afterReal[2]+' '+str_a_afterReal[3])
            print(countCorrect)
            print(countReal)
            # print('Final:'+str(countCorrect/countReal))
            
            ratio = countCorrect/countReal
            print(f'Final: {ratio}')
            data.append({'file_name': fileReal, 'Correctness': ratio})

df_results = pd.DataFrame(data)
df_results.to_excel(pathFileNameResXlsx, index=False)
df_results.to_csv(pathFileNameResCsv, index=False)

# Correctness-HD-GPT35
# Correctness-HD-GPT4
# Correctness-HD-GPT4o
# Correctness-HD-Llama3-70B
# Correctness-MIWG-GPT35
# Correctness-MIWG-GPT4
# Correctness-MIWG-GPT4o
# Correctness-MIWG-Llama3-70B
# Out:
#     event               class         featureName eventType
# 0   event   InstanceHierarchy     internalElement       ADD
# 1   event     InternalElement   externalInterface       ADD
# 2   event   ExternalInterface           baseClass       SET
# 3   event     InternalElement        internalLink       ADD
# 4   event        InternalLink        partnerSideA       SET
# 5   event        InternalLink        partnerSideB       SET
# 6   event     InternalElement                name       SET
# 7   event     InternalElement      baseSystemUnit       SET
# 8   event   ExternalInterface                name       SET
# 9   event   ExternalInterface    refBaseClassPath       SET
# 10  event   ExternalInterface                  iD       SET
# 11  event     InternalElement     internalElement       ADD
# 12  event     InternalElement           attribute       ADD
# 13  event     InternalElement  supportedRoleClass       ADD
# 14  event  SupportedRoleClass           roleClass       SET
# 15  event  SupportedRoleClass    refRoleClassPath       SET
# 16  event           Attribute                name       SET
# 17  event           Attribute               value       SET
# 18  event           Attribute                unit       SET
# 19  event           Attribute   attributeDataType       SET
# 20  event     InternalElement             version       SET
# 21  event   ExternalInterface             version       SET
# 22  event           RoleClass           roleClass       ADD
# 23  event           Attribute        defaultValue       SET
# 24  event     InternalElement           attribute    REMOVE
# 25  event           Attribute           attribute       ADD
# 26  event        InternalLink     refPartnerSideA       SET
# 27  event        InternalLink     refPartnerSideB       SET
# OK
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-07 08.04 Test-representations.airdM.xes
# 19
# 19
# Final: 1.0
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-07 09.06 Test-representations.airdM.xes
# event InternalElement iD SET
# 45
# 46
# Final: 0.9782608695652174
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-07 09.17 Test-representations.airdM.xes
# 29
# 29
# Final: 1.0
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-07 09.27 Test-representations.airdM.xes
# 22
# 22
# Final: 1.0
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-07 09.48 Test-representations.airdM.xes
# 21
# 21
# Final: 1.0
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-07 10.55 Test-representations.airdM.xes
# 20
# 20
# Final: 1.0
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-07 11.07 Test-representations.airdM.xes
# 13
# 13
# Final: 1.0
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-08 09.01 Test-representations.airdM.xes
# event InternalElement refBaseClassPath SET
# 21
# 22
# Final: 0.9545454545454546
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-08 13.19 Test-representations.airdM.xes
# 12
# 12
# Final: 1.0
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-08 14.30 Test-representations.airdM.xes
# 18
# 18
# Final: 1.0
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-09 08.10 Test-representations.airdM.xes
# 20
# 20
# Final: 1.0
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-09 10.13 Test-representations.airdM.xes
# event InternalElement iD SET
# 28
# 29
# Final: 0.9655172413793104
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-09 13.33 Test-representations.airdM.xes
# 19
# 19
# Final: 1.0
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-09 13.37 Test-representations.airdM.xes
# 17
# 17
# Final: 1.0
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-10 08.43 Test-representations.airdM.xes
# 66
# 66
# Final: 1.0
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-10 08.50 Test-representations.airdM.xes
# event InternalElement iD SET
# 23
# 24
# Final: 0.9583333333333334
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-10 08.58 Test-representations.airdM.xes
# 44
# 44
# Final: 1.0
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-10 09.38 Test-representations.airdM.xes
# 66
# 66
# Final: 1.0
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-10 10.09 Test-representations.airdM.xes
# event InternalElement internalElement REMOVE
# 74
# 75
# Final: 0.9866666666666667
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\2023-02-10 10.37 Test-representations.airdM.xes
# event InstanceHierarchy name SET
# event InternalElement iD SET
# 223
# 225
# Final: 0.9911111111111112

# %%
############ HALLUCINATION
import os
import pandas as pd
from collections import Counter

def load_file_lines(path):
    """Loads the content of a file and returns it as a list of lines without newline characters."""
    with open(path, 'r') as file:
        return [line.strip() for line in file.readlines()]

def count_words_by_position(lines):
    """
    Counts occurrences of words by individual positions (first, second, third, fourth),
    as well as combined occurrences of (second and third) and (second, third, fourth) words.
    Returns a list of Counter dictionaries for each position and combination.
    """
    position_counts = [Counter(), Counter(), Counter(), Counter(), Counter(), Counter()]
    
    for line in lines:
        words = line.split()
        # Count individual word positions
        for i, word in enumerate(words[:4]):  # Consider the first 4 words
            position_counts[i][word] += 1
        
        # Count combinations of second and third words
        if len(words) >= 3:
            position_counts[4][f"{words[1]} {words[2]}"] += 1
        
        # Count combinations of second, third, and fourth words
        if len(words) >= 4:
            position_counts[5][f"{words[1]} {words[2]} {words[3]}"] += 1
            
    return position_counts

def calculate_hallucination_metric(counts1, counts2):
    """
    Calculates the "hallucination" metric by taking the ratio of occurrences in counts1
    relative to counts2 for each word position and combination. If a word combination is 
    in counts1 but not in counts2, its occurrence count from counts1 is used directly.
    """
    hallucination_ratios = []
    for i in range(6):  # Loop over each position and combination (first 4 positions + 2 combinations)
        ratio_counter = {}
        for word, count1 in counts1[i].items():
            count2 = counts2[i].get(word, 0)
            if count2 == 0:
                ratio_counter[word] = (count1, count2, count2)  # Store occurrences and hallucination value as count1
            else:
                ratio_counter[word] = (count1, count2, count2 / count1)  # Store occurrences and hallucination ratio
        hallucination_ratios.append(ratio_counter)
    return hallucination_ratios

def compare_directories(dir1, dir2):
    """
    Compares files in the two specified directories for hallucination metrics.
    Only files with the same name in both directories are compared.
    """
    results_by_position = {i: [] for i in range(6)}  # Dictionary to store results for each position
    
    for filename in os.listdir(dir1):
        path1 = os.path.join(dir1, filename)
        path2 = os.path.join(dir2, filename)
        
        if os.path.isfile(path1) and os.path.isfile(path2):
            # Load lines from both files
            lines1 = load_file_lines(path1)
            lines2 = load_file_lines(path2)
            
            # Count word occurrences by position and combination in both files
            counts1 = count_words_by_position(lines1)
            counts2 = count_words_by_position(lines2)
            
            # Calculate hallucination metric for each position and combination
            hallucination_metric = calculate_hallucination_metric(counts1, counts2)
            
            # Append results for each position to the respective lists in results_by_position
            for pos, ratios in enumerate(hallucination_metric):
                for word, (occ1, occ2, ratio) in ratios.items():
                    results_by_position[pos].append({
                        "filename": filename,
                        "word_combination": word,
                        "occurrences_dir1": occ1,
                        "occurrences_dir2": occ2,
                        "hallucination_ratio": ratio
                    })

    # Convert each position's results into DataFrames
    df_results = {
        "First Word": pd.DataFrame(results_by_position[0]),
        "Second Word": pd.DataFrame(results_by_position[1]),
        "Third Word": pd.DataFrame(results_by_position[2]),
        "Fourth Word": pd.DataFrame(results_by_position[3]),
        "Second & Third Words": pd.DataFrame(results_by_position[4]),
        "Second, Third & Fourth Words": pd.DataFrame(results_by_position[5]),
    }
    
    return df_results

pathReal = str(os.getcwd()) + '\CAEX\XES-MORGAN' + '\\'
pathLLM = str(os.getcwd()) + '\CAEX\XES-MORGAN-LLM-MISTRAL' + '\\'
print(pathReal)

# 'XES-MORGAN-LLM-GEMINI', 'XES-MORGAN-LLM-GPT3.5', 'XES-MORGAN-LLM-GPT4', 'XES-MORGAN-LLM-LLAMA3', 
# 'XES-MORGAN-LLM-CLAUDE', 'XES-MORGAN-LLM-MISTRAL'
# 'Hallucination-GEMINI', 'Hallucination-GPT35', 'Hallucination-GPT4', 'Hallucination-LLAMA3', 
# 'Hallucination-CLAUDE', 'Hallucination-MISTRAL'

# Usage example
hallucination_results = compare_directories(pathReal, pathLLM)

# Save the hallucination metrics to an Excel file with each position in a separate sheet
pathFileNameRes = 'results_RQ1/CAEX/Hallucination/Hallucination-MISTRAL.xlsx'
with pd.ExcelWriter(pathFileNameRes) as writer:
    for sheet_name, df in hallucination_results.items():
        df.to_excel(writer, sheet_name=sheet_name, index=False)

# Save each position's results as a separate CSV file
for sheet_name, df in hallucination_results.items():
    csv_path = f"results_RQ1/CAEX/Hallucination/Hallucination-MISTRAL_{sheet_name.replace(' ', '_').lower()}.csv"
    df.to_csv(csv_path, index=False)
    print(f"Saved {sheet_name} metrics to {csv_path}")

# Displaying the DataFrame results for verification (optional)
for sheet_name, df in hallucination_results.items():
    print(f"\n{sheet_name}:\n", df)
# Out:
# C:\Users\vitto\Desktop\github\MASTER-LLM-IST\08_Trace_Quality_Checker\CAEX\XES-MORGAN\
# Saved First Word metrics to results_RQ1/CAEX/Hallucination/Hallucination-MISTRAL_first_word.csv
# Saved Second Word metrics to results_RQ1/CAEX/Hallucination/Hallucination-MISTRAL_second_word.csv
# Saved Third Word metrics to results_RQ1/CAEX/Hallucination/Hallucination-MISTRAL_third_word.csv
# Saved Fourth Word metrics to results_RQ1/CAEX/Hallucination/Hallucination-MISTRAL_fourth_word.csv
# Saved Second & Third Words metrics to results_RQ1/CAEX/Hallucination/Hallucination-MISTRAL_second_&_third_words.csv
# Saved Second, Third & Fourth Words metrics to results_RQ1/CAEX/Hallucination/Hallucination-MISTRAL_second,_third_&_fourth_words.csv
#
# First Word:
#                                             filename word_combination  \
# 0   2023-02-07 08.04 Test-representations.airdM.xes            event
# 1   2023-02-07 09.06 Test-representations.airdM.xes            event
# 2   2023-02-07 09.17 Test-representations.airdM.xes            event
# 3   2023-02-07 09.27 Test-representations.airdM.xes            event
# 4   2023-02-07 09.48 Test-representations.airdM.xes            event
# 5   2023-02-07 10.55 Test-representations.airdM.xes            event
# 6   2023-02-07 11.07 Test-representations.airdM.xes            event
# 7   2023-02-08 09.01 Test-representations.airdM.xes            event
# 8   2023-02-08 13.19 Test-representations.airdM.xes            event
# 9   2023-02-08 14.30 Test-representations.airdM.xes            event
# 10  2023-02-09 08.10 Test-representations.airdM.xes            event
# 11  2023-02-09 10.13 Test-representations.airdM.xes            event
# 12  2023-02-09 13.33 Test-representations.airdM.xes            event
# 13  2023-02-09 13.37 Test-representations.airdM.xes            event
# 14  2023-02-10 08.43 Test-representations.airdM.xes            event
# 15  2023-02-10 08.50 Test-representations.airdM.xes            event
# 16  2023-02-10 08.58 Test-representations.airdM.xes            event
# 17  2023-02-10 09.38 Test-representations.airdM.xes            event
# 18  2023-02-10 10.09 Test-representations.airdM.xes            event
# 19  2023-02-10 10.37 Test-representations.airdM.xes            event
#
#     occurrences_dir1  occurrences_dir2  hallucination_ratio
# 0                 19                23             1.210526
# 1                 46                54             1.173913
# 2                 29                32             1.103448
# 3                 22                33             1.500000
# 4                 21                26             1.238095
# 5                 20                13             0.650000
# 6                 13                13             1.000000
# 7                 22                27             1.227273
# 8                 12                27             2.250000
# 9                 18                18             1.000000
# 10                20                26             1.300000
# 11                29                33             1.137931
# 12                19                26             1.368421
# 13                17                22             1.294118
# 14                66                81             1.227273
# 15                24                26             1.083333
# 16                44                62             1.409091
# 17                66               101             1.530303
# 18                75                36             0.480000
# 19               225               124             0.551111
#
# Second Word:
#                                             filename    word_combination  \
# 0   2023-02-07 08.04 Test-representations.airdM.xes   InstanceHierarchy
# 1   2023-02-07 08.04 Test-representations.airdM.xes     InternalElement
# 2   2023-02-07 08.04 Test-representations.airdM.xes        InternalLink
# 3   2023-02-07 08.04 Test-representations.airdM.xes           Attribute
# 4   2023-02-07 09.06 Test-representations.airdM.xes   InstanceHierarchy
# ..                                              ...                 ...
# 81  2023-02-10 10.09 Test-representations.airdM.xes  SupportedRoleClass
# 82  2023-02-10 10.37 Test-representations.airdM.xes   InstanceHierarchy
# 83  2023-02-10 10.37 Test-representations.airdM.xes     InternalElement
# 84  2023-02-10 10.37 Test-representations.airdM.xes        InternalLink
# 85  2023-02-10 10.37 Test-representations.airdM.xes  SupportedRoleClass
#
#     occurrences_dir1  occurrences_dir2  hallucination_ratio
# 0                  1                 1             1.000000
# 1                 11                 8             0.727273
# 2                  4                 6             1.500000
# 3                  3                 4             1.333333
# 4                  1                 1             1.000000
# ..               ...               ...                  ...
# 81                15                 4             0.266667
# 82                 2                 6             3.000000
# 83               127                38             0.299213
# 84                72                27             0.375000
# 85                24                18             0.750000
#
# [86 rows x 5 columns]
#
# Third Word:
#                                              filename    word_combination  \
# 0    2023-02-07 08.04 Test-representations.airdM.xes     internalElement
# 1    2023-02-07 08.04 Test-representations.airdM.xes                name
# 2    2023-02-07 08.04 Test-representations.airdM.xes   externalInterface
# 3    2023-02-07 08.04 Test-representations.airdM.xes        internalLink
# 4    2023-02-07 08.04 Test-representations.airdM.xes        partnerSideA
# ..                                               ...                 ...
# 173  2023-02-10 10.37 Test-representations.airdM.xes        internalLink
# 174  2023-02-10 10.37 Test-representations.airdM.xes        partnerSideA
# 175  2023-02-10 10.37 Test-representations.airdM.xes        partnerSideB
# 176  2023-02-10 10.37 Test-representations.airdM.xes  supportedRoleClass
# 177  2023-02-10 10.37 Test-representations.airdM.xes           roleClass
#
#      occurrences_dir1  occurrences_dir2  hallucination_ratio
# 0                   2                 2             1.000000
# 1                   4                 7             1.750000
# 2                   4                 2             0.500000
# 3                   2                 2             1.000000
# 4                   2                 2             1.000000
# ..                ...               ...                  ...
# 173                22                 9             0.409091
# 174                36                 9             0.250000
# 175                36                 9             0.250000
# 176                22                 9             0.409091
# 177                24                 9             0.375000
#
# [178 rows x 5 columns]
#
# Fourth Word:
#                                             filename word_combination  \
# 0   2023-02-07 08.04 Test-representations.airdM.xes              ADD
# 1   2023-02-07 08.04 Test-representations.airdM.xes              SET
# 2   2023-02-07 09.06 Test-representations.airdM.xes              ADD
# 3   2023-02-07 09.06 Test-representations.airdM.xes              SET
# 4   2023-02-07 09.06 Test-representations.airdM.xes           REMOVE
# 5   2023-02-07 09.17 Test-representations.airdM.xes              ADD
# 6   2023-02-07 09.17 Test-representations.airdM.xes              SET
# 7   2023-02-07 09.27 Test-representations.airdM.xes              ADD
# 8   2023-02-07 09.27 Test-representations.airdM.xes              SET
# 9   2023-02-07 09.48 Test-representations.airdM.xes              ADD
# 10  2023-02-07 09.48 Test-representations.airdM.xes              SET
# 11  2023-02-07 10.55 Test-representations.airdM.xes              ADD
# 12  2023-02-07 10.55 Test-representations.airdM.xes              SET
# 13  2023-02-07 11.07 Test-representations.airdM.xes              ADD
# 14  2023-02-07 11.07 Test-representations.airdM.xes              SET
# 15  2023-02-08 09.01 Test-representations.airdM.xes              ADD
# 16  2023-02-08 09.01 Test-representations.airdM.xes              SET
# 17  2023-02-08 13.19 Test-representations.airdM.xes              ADD
# 18  2023-02-08 13.19 Test-representations.airdM.xes              SET
# 19  2023-02-08 14.30 Test-representations.airdM.xes              ADD
# 20  2023-02-08 14.30 Test-representations.airdM.xes              SET
# 21  2023-02-09 08.10 Test-representations.airdM.xes              ADD
# 22  2023-02-09 08.10 Test-representations.airdM.xes              SET
# 23  2023-02-09 10.13 Test-representations.airdM.xes              ADD
# 24  2023-02-09 10.13 Test-representations.airdM.xes              SET
# 25  2023-02-09 13.33 Test-representations.airdM.xes              ADD
# 26  2023-02-09 13.33 Test-representations.airdM.xes              SET
# 27  2023-02-09 13.37 Test-representations.airdM.xes              ADD
# 28  2023-02-09 13.37 Test-representations.airdM.xes              SET
# 29  2023-02-10 08.43 Test-representations.airdM.xes              ADD
# 30  2023-02-10 08.43 Test-representations.airdM.xes              SET
# 31  2023-02-10 08.50 Test-representations.airdM.xes              ADD
# 32  2023-02-10 08.50 Test-representations.airdM.xes              SET
# 33  2023-02-10 08.58 Test-representations.airdM.xes              ADD
# 34  2023-02-10 08.58 Test-representations.airdM.xes              SET
# 35  2023-02-10 09.38 Test-representations.airdM.xes              ADD
# 36  2023-02-10 09.38 Test-representations.airdM.xes              SET
# 37  2023-02-10 10.09 Test-representations.airdM.xes           REMOVE
# 38  2023-02-10 10.09 Test-representations.airdM.xes              SET
# 39  2023-02-10 10.09 Test-representations.airdM.xes              ADD
# 40  2023-02-10 10.37 Test-representations.airdM.xes              ADD
# 41  2023-02-10 10.37 Test-representations.airdM.xes              SET
#
#     occurrences_dir1  occurrences_dir2  hallucination_ratio
# 0                  9                 7             0.777778
# 1                 10                16             1.600000
# 2                 13                17             1.307692
# 3                 32                37             1.156250
# 4                  1                 0             0.000000
# 5                 12                11             0.916667
# 6                 17                21             1.235294
# 7                  7                11             1.571429
# 8                 15                22             1.466667
# 9                  8                 9             1.125000
# 10                13                17             1.307692
# 11                 9                 4             0.444444
# 12                11                 9             0.818182
# 13                 4                 4             1.000000
# 14                 9                 9             1.000000
# 15                 7                10             1.428571
# 16                15                17             1.133333
# 17                 4                 8             2.000000
# 18                 8                19             2.375000
# 19                 8                 6             0.750000
# 20                10                12             1.200000
# 21                10                 9             0.900000
# 22                10                17             1.700000
# 23                11                12             1.090909
# 24                18                21             1.166667
# 25                 9                 8             0.888889
# 26                10                18             1.800000
# 27                 6                 7             1.166667
# 28                11                15             1.363636
# 29                23                31             1.347826
# 30                43                50             1.162791
# 31                 9                 9             1.000000
# 32                15                17             1.133333
# 33                18                24             1.333333
# 34                26                38             1.461538
# 35                25                39             1.560000
# 36                41                62             1.512195
# 37                 1                 0             0.000000
# 38                44                23             0.522727
# 39                30                13             0.433333
# 40                88                46             0.522727
# 41               137                78             0.569343
#
# Second & Third Words:
#                                              filename  \
# 0    2023-02-07 08.04 Test-representations.airdM.xes
# 1    2023-02-07 08.04 Test-representations.airdM.xes
# 2    2023-02-07 08.04 Test-representations.airdM.xes
# 3    2023-02-07 08.04 Test-representations.airdM.xes
# 4    2023-02-07 08.04 Test-representations.airdM.xes
# ..                                               ...
# 207  2023-02-10 10.37 Test-representations.airdM.xes
# 208  2023-02-10 10.37 Test-representations.airdM.xes
# 209  2023-02-10 10.37 Test-representations.airdM.xes
# 210  2023-02-10 10.37 Test-representations.airdM.xes
# 211  2023-02-10 10.37 Test-representations.airdM.xes
#
#                        word_combination  occurrences_dir1  occurrences_dir2  \
# 0     InstanceHierarchy internalElement                 1                 1
# 1       InternalElement internalElement                 1                 1
# 2                  InternalElement name                 3                 2
# 3     InternalElement externalInterface                 4                 2
# 4          InternalElement internalLink                 2                 2
# ..                                  ...               ...               ...
# 207        InternalElement internalLink                22                 9
# 208           InternalLink partnerSideA                36                 9
# 209           InternalLink partnerSideB                36                 9
# 210  InternalElement supportedRoleClass                22                 9
# 211        SupportedRoleClass roleClass                24                 9
#
#      hallucination_ratio
# 0               1.000000
# 1               1.000000
# 2               0.666667
# 3               0.500000
# 4               1.000000
# ..                   ...
# 207             0.409091
# 208             0.250000
# 209             0.250000
# 210             0.409091
# 211             0.375000
#
# [212 rows x 5 columns]
#
# Second, Third & Fourth Words:
#                                              filename  \
# 0    2023-02-07 08.04 Test-representations.airdM.xes
# 1    2023-02-07 08.04 Test-representations.airdM.xes
# 2    2023-02-07 08.04 Test-representations.airdM.xes
# 3    2023-02-07 08.04 Test-representations.airdM.xes
# 4    2023-02-07 08.04 Test-representations.airdM.xes
# ..                                               ...
# 209  2023-02-10 10.37 Test-representations.airdM.xes
# 210  2023-02-10 10.37 Test-representations.airdM.xes
# 211  2023-02-10 10.37 Test-representations.airdM.xes
# 212  2023-02-10 10.37 Test-representations.airdM.xes
# 213  2023-02-10 10.37 Test-representations.airdM.xes
#
#                            word_combination  occurrences_dir1  \
# 0     InstanceHierarchy internalElement ADD                 1
# 1       InternalElement internalElement ADD                 1
# 2                  InternalElement name SET                 3
# 3     InternalElement externalInterface ADD                 4
# 4          InternalElement internalLink ADD                 2
# ..                                      ...               ...
# 209        InternalElement internalLink ADD                22
# 210           InternalLink partnerSideA SET                36
# 211           InternalLink partnerSideB SET                36
# 212  InternalElement supportedRoleClass ADD                22
# 213        SupportedRoleClass roleClass SET                24
#
#      occurrences_dir2  hallucination_ratio
# 0                   1             1.000000
# 1                   1             1.000000
# 2                   2             0.666667
# 3                   2             0.500000
# 4                   2             1.000000
# ..                ...                  ...
# 209                 9             0.409091
# 210                 9             0.250000
# 211                 9             0.250000
# 212                 9             0.409091
# 213                 0             0.000000
#
# [214 rows x 5 columns]
